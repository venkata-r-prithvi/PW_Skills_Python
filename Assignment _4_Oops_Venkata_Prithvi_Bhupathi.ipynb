# %%
#1.What is Object-Oriented Programming (OOP)?
'''
OOPS is a programming approach that organises the "software design" around the "objects",which are 
"instances of classes".
OOPS helps in code maintainence,resuability and modular.
'''

# %%
#2.What is a class in OOPS
"""
Class is a template/blue print that "defines a stucture or behaviour" for objects. It specifies the data
"attributes" and actions(methods) that objects created form it will have.

"""

# %%
#3.What is an object in OOPS
"""
Object : in OOPS is specific instance of a class that contains its own data(attributes) and 
can perform actions(methods) each object is unique with in a state and behaviour.

"""

# %%
#4 What is the difference between abstraction and encapsulation
"""
Abstraction : "Hides" the "complex details" and shows only "essential features" making 
system easier to use and maintain.
-It is also "what"an object does.
Encapsulation : "Bundles the data and methods together",restricting "direct access" to data and security.
-It is also "How" an object does.
"""

# %%
#5.What are dunder methods in Python
"""
Dunder Methods: are special/magic methods that "__start and end with __" ex:__init__,__str__
-They are also called as Magic methods and are used to how the objects behave with built in operations.
- They are "automatically called by python " for specific actions but not by users directly.
"""

# %%
#6.Explain the concept of inheritance in OOP
"""
Inheritance is a mechanism in which class can inherit (child class) propeties and behaviour from 
another class (superclass/parentclass).
- It allows the code to be reused, orgainsed and maintained.
- There are multiple types inheritances i.e single, multiple,multilevel etc.
"""

# %%
#7. What is polymorphism in OOP
"""
Polymorphism is ability of object to take different forms and behave differently based on context 
in which they are used.
- It allows a single interface to be used for different types of objects enabling methods 
to act differently depending upon object calling them
- It is acheieved through inheritance,method over riding and interfaces.
"""

# %%
#8.How is encapsulation achieved in Python
"""
Encapsulation is acheieved by "bundling" the data and methods together",restricting "direct access" 
to data and security.
- we use _ for protected members and __ for private members to restrict "direct access" from 
outside class.

"""

# %%
#9. What is a constructor in Python?
"""
Constructor is a "special method" called automatically when an object is created from a class"

-Its main purpose is to initialise the obhject by "setting up its attributes or state "

-Ex most common constructor is __init__

"""

# %%
#10. What are class and static methods in Python
"""
Class method : is defined using "@classmethod" decorator and uses "cls"as first parameter.
_ It can access and modify "class level data" making it useful for operations that affect all
levels of class.
Static Method : is defined using "@staticmethod" decorator and does "not take any special first parameter"
-It cannot access ,modify class or instance data. Useful as utility functions that logically belong 
to class but donot depend upon the state.

"""

# %%
# 11 What is method overloading in Python?
"""
Method Overloading : allows to have a "Multiple Methods" with same name but different parameters.
- Is a type of "Compile time Polymorphism"
- Approach increases code flexibilty and readability.
- Ex: calculator having separate methods for adding two numbers and three numbers.
"""

# %%
#12. What is method overriding in OOP ?
"""
Method Overiding :allows a subclass to provide its own implementation of a method already defined in 
its parent class.
-The method in the subclass must have the same name, parameters, and return type as in the parent class.
-Ex :  a "Vehicle" class with a "start" method, and a "Car" subclass having its own "start" method.

"""

# %%
#13.What is a property decorator in Python?
"""
Property Decorator : Python allows methods to be accessed like attributes, providing controlled access 
to class data.
-It is used to define getter, setter, and deleter methods for an attribute, enabling validation 
or logic during access.
-This makes attribute handling safer and more flexible without changing how the attribute is used in code.

"""

# %%
#14.  Why is polymorphism important in OOP
"""
Polymorphism is important in OOP because it allows objects of different types to be treated as instances 
of a common interface, making code more flexible and reusable.

-It enables writing generic functions that work with various object types, reducing code duplication and
making the system easier to maintain and extend.

"""

# %%
#15.What is an abstract class in Python
"""
An abstract class in Python is a blueprint for other classes and cannot be instantiated directly.

It defines methods that must be implemented by its subclasses, ensuring a consistent interface.

Abstract classes are created using the abc module and the @abstractmethod decorator.

"""

# %%
#16. What are the advantages of OOP
"""
OOPS improves code organization, making it easier to manage and maintain large projects.

-It promotes code reusability through inheritance, reducing redundancy and development time.

-It enhances flexibility and scalability, allowing systems to grow and adapt easily.

-It supports better collaboration, as different developers can work on separate classes without 
interference.

-It simplifies debugging and troubleshooting by isolating issues to specific classes 
"""

# %%
#17. What is the difference between a class variable and an instance variable
"""
A class variable is shared by all instances of a class and is defined at the class level;

changes to it affect all objects.

An instance variable is unique to each object and is defined within methods, typically in the constructor; 

changes to it affect only that specific instance.

Class variables are useful for data common to all instances, while instance variables store

individual object-specific data.

# %%
#18.What is multiple inheritance in Python?
"""
Multiple inheritance in Python allows a class to inherit attributes and methods from more than one 
parent class.

-This enables code reuse and the creation of complex class hierarchies by combining features from
multiple sources.

-Python resolves method calls using the Method Resolution Order (MRO), which determines the sequence in

which parent classes are searched
"""

# %%
#19.Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python

"""
The __str__ method provides a human-readable string representation of an object, mainly for end users 

or display purposes.

The __repr__ method returns a detailed, developer-focused string that ideally can recreate the object, 

used for debugging and logging.

If __str__ is missing, Python uses __repr__ as a fallback for string representation.

"""

# %%
#20.What is the significance of the ‘super()’ function in Python

"""
The super() function in Python allows a subclass to call methods and access properties from its parent 

class, enabling code reuse and extension of inherited functionality.

It is especially useful in inheritance scenarios, as it avoids hardcoding parent class names and 

supports both single and multiple inheritance.

"""

# %%
#21.What is the significance of the __del__ method in Python
"""
The __del__ method in Python acts as a destructor, called automatically when an object is about 

to be destroyed and garbage collected.

-Its main purpose is to perform cleanup actions, such as releasing external resources like file handles 

or network connections, ensuring resources are not leaked.

This method helps maintain code stability and reliability by providing a way to clean up 

before an object is removed from memory.

"""

# %%
#22.What is the difference between @staticmethod and @classmethod in Python
"""
-@staticmethod decorator defines a method that does not receive any implicit first argument 

and cannot access or modify class or instance state; it behaves like a regular function grouped 

within a class.

-@classmethod decorator defines a method that receives the class (cls) as its first argument,

allowing it to access and modify class-level attributes and methods, but not instance-specific data.

Use @staticmethod for utility functions independent of class or instance, and @classmethod for 

methods that need to work with class data or act as alternative constructors.

"""

# %%
#23.How does polymorphism work in Python with inheritance
"""
Polymorphism with inheritance allows subclasses to override methods from their parent class

so the same method name can behave differently for each subclass.

-When a method is called on an object, Python determines at runtime which version to 

execute based on the object's actual class.

-Polymorphism simplifies code maintenance and enhances flexibility by supporting dynamic

method resolution.

"""

# %%
#24.What is method chaining in Python OOP?
"""
Method chaining in Python OOP allows multiple methods to be called on the same object in a single line, 

making code concise and readable.

Each method in the chain must return an object, usually the same object (self), so the next method

can operate on it.

"""

# %%
#25.What is the purpose of the __call__ method in Python?

"""
The __call__ method allows an instance of a class to be called like a function, making objects 

behave as callable entities.

When an object is called using parentheses, Python automatically invokes its __call__ method, 

enabling flexible and reusable code.

This is useful for creating objects that maintain state and can be used as parameterized functions 

or for implementing design patterns like decorators and strategies

"""

# %%
#Practial Questions

# %%
# 1. WAP parent class Animal with a method speak() that prints a generic message. Create a child class 
#Dog that overrides the speak() method to print "Bark!".

# %%
class Animal(): # Animal class is created.
    def speak(self):
        print("This is generic Message")
class Dog(Animal): # Child class inherits parent class
    def speak(self):
        print(" Barks as BOW BOW")

# %%
anm = Dog() # Object is created
anm.speak() # over rides speak() method to print Bark..as shown below
# Out:
#  Barks as BOW BOW

# %%
#2.Write a program to create an abstract class Shape with a method area(). Derive classes Circle and 
#Rectangle from it and implement the area() method in both.
#Use an abstract class when you want to define a common structure or base behavior for a group of 
#related classes,

from abc import ABC, abstractmethod #Methods are imported

class Shape(ABC): #Abstarct Class is created
    @abstractmethod 
    def area(self):
        pass
class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius
    def area(self):
        return 3.14 * self.radius ** 2 #returns area of circle
class Rectangle(Shape):
    def __init__(self,length,breadth): 
        self.length = length
        self.breadth = breadth
    def area(self):
        return self.length * self.breadth #returns area of rectangle
         
A_O_C = Circle(5)
A_O_C.area()
# Out:
# 78.5

# %%
A_O_R = Rectangle(5,6)
A_O_R.area()
# Out:
# 30

# %%
#3.Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. 
#Derive a class Car and further derive a class ElectricCar that adds a battery attribute.
class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type

class Car(Vehicle):
    def __init__(self, vehicle_type, car_type):
        super().__init__(vehicle_type)  # Initialize Vehicle's type
        self.car_type = car_type         # Add car_type attribute

class Electric_Car(Car):
    def __init__(self, vehicle_type, car_type, battery):
        super().__init__(vehicle_type, car_type)  # Initialize Car
        self.battery = battery                    # Add battery attribute

# %%
my_car = Electric_Car("car", "BMW", 90)
print(my_car.type)       # Output: car
print(my_car.car_type)   # Output: BMW
print(my_car.battery)    # Output: 90
# Out:
# car
# BMW
# 90

# %%
my_car.car_type
# Out:
# 'BMW'

# %%
#4.Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
#Sparrow and Penguin that override the fly() method.
class Bird():
    def fly(self):
        return "This bird can fly"
class Sparrow(Bird):
    def fly(self):
        return "This bird can fly to a good height"

class Penguin(Bird):
    def fly (self):
        return"this bird cannot fly"

# %%
birds = [Sparrow(),Penguin(),Bird()]
for bird in birds:
    print(bird.fly()) # we can clearly see the over ride in fly() method.
# Out:
# This bird can fly to a good height
# this bird cannot fly
# This bird can fly

# %%
#5.Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
#balance and methods to deposit, withdraw, and check balance.
#private variables are given by __

class BankAccount():
    def __init__(self,balance=0):
        self.__balance = balance #setting up balance as private
        
    def deposit(self,amount): #Deposit Method 
        if amount >0: #amount has to be positive
            self.__balance += amount
            print(f"deposited: = {amount}")
        else:
            print("Invalid amount for deposit")
            
    def withdraw(self,amount): #withDraw Method 
        if 0<amount<=self.__balance: # checking for enough balance available or not for withdrawl
            self.__balance -= amount
            print(f"Withdrawn: {amount}")
        else:
            print("Invalid amount for withdrawal or insufficient balance")

    def check_balance(self): # Check Balance 
        print(f"Balance: {self.__balance}")

# %%
acc = BankAccount(1000)
acc.check_balance()
# Out:
# Balance: 1000

# %%
acc.deposit(500)
# Out:
# deposited: = 500

# %%
acc.withdraw(1000)
# Out:
# Withdrawn: 1000

# %%
acc.check_balance()
# Out:
# Balance: 500

# %%
#6.. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes 
#Guitar and Piano that implement their own version of play().

class Instrument:
    def play(self):
        return "The instrument plays beautiful tones"

class Guitar(Instrument):
    def play(self):
        return "You need a different skill to play guitar"

class Piano(Instrument):
    def play(self):
        return "You need both hands to play beautiful music"


# output
instruments = [Guitar(), Piano(), Instrument()]
for inst in instruments:
    print(inst.play())
# Out:
# You need a different skill to play guitar
# You need both hands to play beautiful music
# The instrument plays beautiful tones

# %%
#7.Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.
class MathOperations():
    @classmethod
    def add_numbers(cls,a,b):
        return a + b

    @staticmethod
    def sub_numbers(a,b):
        return a - b
print("Addition:", MathOperations.add_numbers(90, 50))        # Output: 15
print("Subtraction:", MathOperations.sub_numbers(100, 50))
# Out:
# Addition: 140
# Subtraction: 50

# %%
#8. Implement a class Person with a class method to count the total number of persons created

class Person():
    person_count = 0  # Class variable to keep track
    def __init__(self, name):
        self.name = name
        Person.person_count += 1  # Increment count on object creation

    @classmethod
    def count_no_person(cls):
        return cls.person_count  # Return the total count

# Example usage
p1 = Person("Pritz")
p2 = Person("Bhupathi")
p3 = Person("Venkata")
print("Total persons created:", Person.count_no_person())
# Out:
# Total persons created: 3

# %%
#9.Write a class Fraction with attributes numerator and denominator. Override the str method to display 
#the fraction as "numerator/denominator".
class Fraction:
    def __init__(self,numerator,denominator):
        self.numerator = numerator
        self.denominator = denominator
    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# %%
frac = Fraction(5,6)
print(frac)
# Out:
# 5/6

# %%
#10.Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
#vectors
class Vector:
    def __init__(self,x,y): 
        self.x = x
        self.y = y
    def __add__(self, other): 
        if isinstance(other, Vector):#checks for specific class or not
            return Vector(self.x + other.x, self.y + other.y)
        else:
            return NotImplemented

    def __str__(self): 
        return f"Vector({self.x}, {self.y})" #helps readability

# %%
v1 = Vector(4, 8)
v2 = Vector(16, 32)
v3 = v1 + v2
print(v3)
# Out:
# Vector(20, 40)

# %%
#11.Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
#{name} and I am {age} years old."
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def greet(self):
        return f"Hello ,My name is {self.name} and I am {self.age} years old"

# %%
person = Person("Pritz","35")
print(person.greet())
# Out:
# Hello ,My name is Pritz and I am 35 years old

# %%
#12.Implement a class Student with attributes name and grades. Create a method average_grade() to compute
#the average of the grades
class Student:
    def __init__(self,name,grades):
        self.name = name
        self.grades = grades
    def average_grade(self):
        if self.grades:
            return sum(self.grades) / len(self.grades)  # Calculate average
        else:
            return 0  # Return 0 for empty list

# %%
student = Student("Bhupathi", [85, 99, 88, 90])
print(student.average_grade())
# Out:
# 90.5

# %%
#13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() 
#to calculate the area.
class Rectangle:
    # Initialize the Rectangle with default length and width to zero
    
    def __init__(self):
        self.length = 0
        self.width = 0
  
    def set_dimensions(self, length, width):  # Method to set the dimensions of the rectangle
        # Checks that both length and width are positive numbers
        if length > 0 and width > 0:  
            self.length = length
            self.width = width
        else:
            raise ValueError("Dimensions must be positive numbers")

    # Method to calculate and return the area of the rectangle
    def area(self):
        return self.length * self.width

# output
rect = Rectangle()
rect.set_dimensions(8, 8)
print("Area:", rect.area())  # Output: 64
# Out:
# Area: 64

# %%
#14.Create a class Employee with a method calculate_salary() that computes the salary based on hours 
#worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.
class Employee:
    def __init__(self,name,hours_worked,hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate
    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate #salary calculated
        
class Manager(Employee):
    def __init__(self,name,hours_worked,hourly_rate,bonus):
        super().__init__(name,hours_worked,hourly_rate) #from parent class
        self.bonus = bonus
    def calculate_salary(self):
        base_salary = super().calculate_salary()  # Get base salary from parent class
        return base_salary + self.bonus

# %%
emp = Employee("Venkat", 40, 40)
print(f"{emp.name}'s salary: {emp.calculate_salary()}")  

mgr = Manager("Pritz", 40, 40, 1000)
print(f"{mgr.name}'s salary: {mgr.calculate_salary()}")
# Out:
# Venkat's salary: 1600
# Pritz's salary: 2600

# %%
#15.Create a class Product with attributes name, price, and quantity. Implement a method total_price()
#that calculates the total price of the product.

class Product:
    def __init__(self,name,price,quantity):
        self.name = name
        self.price = price
        self.quantity = quantity
    def total_price(self):
        return self.price * self.quantity

# %%
product = Product("Laptop", 75000, 2)
print(f"Total price: {product.total_price()}")
# Out:
# Total price: 150000

# %%
#16.Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
#implement the sound() method.

from abc import ABC, abstractmethod #Methods are imported

class Animal():
    @abstractmethod
    def sound(ABC):
        pass
class Cow(Animal):
    def sound(self):
        return "Cow sounds like MOOOO"
class Sheep(Animal):
    def sound(self):
        return "Sheep sounds like BAAA"

# %%
cow = Cow()
sheep = Sheep()
print(cow.sound()) 
print(sheep.sound())
# Out:
# Cow sounds like MOOOO
# Sheep sounds like BAAA

# %%
#17.Create a class Book with attributes title, author, and year_published. 
#Add a method get_book_info() that returns a formatted string with the book's details.
class Book:
    def __init__(self,title,author,year_published):
        self.title = title
        self.author = author
        self.year_published = year_published
    def get_book_info(self):
        return f"{self.title},{self.author},{self.year_published}"

# %%
book_details = Book("Python","Bhupathi","2025")
print(book_details.get_book_info())
# Out:
# Python,Bhupathi,2025

# %%
#18.Create a class House with attributes address and price. Create a derived class Mansion that adds an
#attribute number_of_rooms.
class House():
    def __init__(self,address,price):
        self.address = address
        self.price = price
class Mansion(House):
    def __init__(self,address,price,number_of_rooms):
        super().__init__(address,price)
        self.number_of_rooms = number_of_rooms

# %%
mansion = Mansion("190/2RT,Vijay Nagar Colony", 1500000, 8)
print(f"Mansion: {mansion.address}, Price: {mansion.price}, Rooms: {mansion.number_of_rooms}")
# Out:
# Mansion: 190/2RT,Vijay Nagar Colony, Price: 1500000, Rooms: 8
